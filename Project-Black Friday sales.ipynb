# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\HP\OneDrive\Documents\BlackFriday.csv")
df.sample(10)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 126086  1001442  P00191442      M  18-25           2             A
# 155984  1000075  P00317842      F   0-17          10             C
# 403258  1001998  P00287542      F  51-55           9             B
# 506605  1000002  P00115542      M    55+          16             C
# 244328  1001645  P00230942      F  18-25           9             B
# 162683  1001150  P00111942      F  26-35          20             A
# 152379  1005550  P00100442      M  36-45          15             B
# 146634  1004582  P00113142      F  26-35           0             A
# 361377  1001639  P00046242      M  26-35          17             B
# 107016  1004459  P00279542      M  26-35           1             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 126086                          3               0                   1
# 155984                         4+               0                   8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.drop(columns={'Product_Category_2','Product_Category_3'},inplace=True)
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3623
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               18
# Purchase                      17959
# dtype: int64

# %%
df['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby('Gender').size().plot(kind='bar',figsize=(6,6))
# Out:
# <Axes: xlabel='Gender'>

# %%
df['Gender'].value_counts().plot(kind='pie',autopct='%.2f',title="Gender Ratio",figsize=(5,5))
# Out:
# <Axes: title={'center': 'Gender Ratio'}, ylabel='count'>

# %%
df.groupby('Gender').sum(numeric_only=True)['Purchase'].plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Gender').mean(numeric_only=True)['Purchase'].plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
sns.barplot(data=df,x='Gender',y='Purchase')
# Out:
# <Axes: xlabel='Gender', ylabel='Purchase'>

# %%
df.groupby('Age').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby('Age').size()#Total number of purchases of the age groups
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
dfn=df.groupby('Age').nunique()['Product_ID']
dfn#Total number of unique product purchases
# Out:
# Age
# 0-17     2300
# 18-25    3213
# 26-35    3419
# 36-45    3318
# 46-50    3099
# 51-55    2877
# 55+      2573
# Name: Product_ID, dtype: int64

# %%
dfpd=pd.DataFrame((dfn))
dfpd
# Out:
#        Product_ID
# Age
# 0-17         2300
# 18-25        3213
# 26-35        3419
# 36-45        3318
# 46-50        3099
# 51-55        2877
# 55+          2573

# %%
dfpd.reset_index()
# Out:
#      Age  Product_ID
# 0   0-17        2300
# 1  18-25        3213
# 2  26-35        3419
# 3  36-45        3318
# 4  46-50        3099
# 5  51-55        2877
# 6    55+        2573

# %%
dfpd.plot.bar(figsize=(8,6))
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby('Age').sum(numeric_only=True)['Purchase']
# Out:
# Age
# 0-17      132659006
# 18-25     901669280
# 26-35    1999749106
# 36-45    1010649565
# 46-50     413418223
# 51-55     361908356
# 55+       197614842
# Name: Purchase, dtype: int64

# %%
df.groupby('Age').sum(numeric_only=True)['Purchase'].plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
sns.barplot(x='Age',y='Purchase',data=df,width=0.8)
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %%
df.groupby("Age").mean(numeric_only=True)['Purchase'].plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Marital_Status').size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
sns.countplot(data=df,x='Age',hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(data=df,x="Marital_Status",hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(data=df,x='City_Category',hue='Age')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(data=df,x="Marital_Status",hue="City_Category")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
df.groupby("City_Category").sum(numeric_only=True)["Purchase"].plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
sns.barplot(data=df,x='Age',y='Purchase',estimator='sum',hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %%
 df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
sns.countplot(data=df,x='Stay_In_Current_City_Years')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=df,x='Stay_In_Current_City_Years',hue='Gender')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df['Marital_Status']=df['Marital_Status'].astype('str')
df.dtypes
# Out:
# User_ID                        int64
# Product_ID                    object
# Gender                        object
# Age                           object
# Occupation                     int64
# City_Category                 object
# Stay_In_Current_City_Years    object
# Marital_Status                object
# Product_Category_1             int64
# Purchase                       int64
# dtype: object

# %%
sns.countplot(data=df,x='Stay_In_Current_City_Years',hue="Marital_Status")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.barplot(data=df,x='Stay_In_Current_City_Years',y='Purchase',estimator='sum')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='Purchase'>

# %%
sns.countplot(data=df,x='Occupation')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').sum(numeric_only=True)['Purchase'].sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').mean(numeric_only=True)['Purchase'].sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').mean(numeric_only=True)['Purchase'].sort_values()
# Out:
# Occupation
# 9     8714.335934
# 19    8754.249162
# 20    8881.099514
# 1     9017.703095
# 2     9025.938982
# 10    9052.836410
# 0     9186.946726
# 18    9233.671418
# 3     9238.077277
# 4     9279.026742
# 11    9299.467190
# 6     9336.378620
# 5     9388.848978
# 13    9424.449391
# 16    9457.133118
# 7     9502.175276
# 14    9568.536426
# 8     9576.508530
# 15    9866.239925
# 12    9883.052460
# 17    9906.378997
# Name: Purchase, dtype: float64

# %%
df.groupby("Occupation").nunique()['Product_ID'].sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Product_Category_1").size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1").sum(numeric_only=True)['Purchase'].sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1").mean(numeric_only=True)['Purchase'].sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_ID').sum()['Purchase'].nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby('Product_ID').size().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby('Product_ID').mean(numeric_only=True)['Purchase'].nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>
